# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
jobs = pd.read_csv('./data/glassdoor_jobs.csv')
jobs
# Out:
#                                                 title  \
# 0                              Data Scientist (w/m/d)
# 1                       Senior Data Scientist (m/w/d)
# 2   Data Scientist, Informatiker - Enterprise Data...
# 3                        Data Scientist/Data Engineer
# 4   Data Scientist (w/m/d) mit Masterstudium an TH...
# 5          Data Scientist NLP and Text Mining (f/m/d)
# 6                              Data Scientist (m/w/d)
# 7           Data Scientist / Feature Engineer (m/w/d)
# 8                       Junior Data Scientist (f/m/x)
# 9   Data Scientist - Clinical Computational Proteo...
# 10  Data Scientist (m/w/d) als Teamleiter Data Ana...
# 11                                     Data Scientist
# 12              Senior Data Platform Engineer (m/f/d)
# 13            Data Scientist (m/f/d) Exploration team
# 14  Data Scientist - Datenbanken / Prozessoptimier...
# 15                             Data Scientist (m/w/d)
# ...

# %%
# plot the distribution of the location of the jobs
jobs['location'].value_counts().plot(kind='bar', figsize=(20, 10));
